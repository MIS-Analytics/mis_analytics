# %% [raw]
# ---
# description: Fill in a module description here
# output-file: core.html
# title: core
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(foo)
# Out:
# ---
#
# ### foo
#
# >      foo ()

# %%
#| echo: false
#| output: asis
show_doc(move_columns)
# Out:
# ---
#
# ### move_columns
#
# >      move_columns (df:pandas.core.frame.DataFrame, cols_to_move:str, pos:int)
#
# *Move one or more columns to a specified position in a DataFrame.*
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | df | DataFrame | Input |
# | cols_to_move | str | Single |
# | pos | int | Target |
# | **Returns** | **DataFrame** |  |

# %%
def username():
    "Get the current user's name."
    return "Jeremy"

# %% [markdown]
# get the username via &`username`
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
#
#
# <details class='tool-usage-details'>
#
# ```json
# {
#   "id": "toolu_01NvBFPBxus9HT6YDpZ9QDP3",
#   "call": {
#     "function": "username",
#     "arguments": {}
#   },
#   "result": "'Jeremy'"
# }
# ```
#
# </details>
#
# The username is "Jeremy".

# %% [markdown]
# Please create a simple dataframe
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Here's a simple dataframe for you:
#
# ```python
# df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6], 'C': [7, 8, 9]})
# ```
#
# Would you like to see what it looks like, or would you prefer to work with different data?

# %%
df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6], 'C': [7, 8, 9]})
df
# Out:
#    A  B  C
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
move_columns(df, 'C', 0)
# Out:
#    C  A  B
# 0  7  1  4
# 1  8  2  5
# 2  9  3  6
